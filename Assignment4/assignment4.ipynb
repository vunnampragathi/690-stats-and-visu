# %% [markdown]
# <a href="https://colab.research.google.com/github/vunnampragathi/690-stats-and-visu/blob/main/Assignment4/assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # assignment 4
#
# name: Pragathi
#
# date:09/22/2022

# %% [markdown]
# using 2017-2018 file from the college score card data

# %%
import pandas as pd
data = pd.read_csv("/content/MERGED2017_18_PP.csv")        # reading the 2017-18 data
data
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (1729) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         UNITID    OPEID  OPEID6  \
# 0       100654   100200    1002
# 1       100663   105200    1052
# 2       100690  2503400   25034
# 3       100706   105500    1055
# 4       100724   100500    1005
# ...        ...      ...     ...
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM             CITY  \
# 0                              Alabama A & M University           Normal
# 1                   University of Alabama at Birmingham       Birmingham
# 2                                    Amridge University       Montgomery
# ...

# %%
data.shape   # displaying the size of the data which gives number of rows and columns
# Out:
# (7112, 1986)

# %% [markdown]
# number of rows or colleges is 7112
#
# number of columns or variables is 1986

# %% [markdown]
# Looking at the first 5 colleges

# %%
data.head(5)   # printing first 5 rows in the data
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
# 2     AL  36117-3553           NaN      NaN     NaN  ...
# 3     AL       35899           NaN      NaN     NaN  ...
# 4     AL  36104-0271           NaN      NaN     NaN  ...
#
#    OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN   UG12MN   G12MN  \
# 0                           NaN       0.7106        0.7418   5207.0  1185.0
# ...

# %% [markdown]
# Looking at the last 5 colleges

# %%
data.tail(5)  # printing last 5 rows in data
# Out:
#         UNITID    OPEID  OPEID6  \
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM             CITY  \
# 7107                   Arizona State University at Yuma             Yuma
# 7108  Bay Area Medical Academy - San Jose Satellite ...         San Jose
# 7109           High Desert Medical College - Bakerfield      Bakersfield
# 7110                                       BCI - Malden           Malden
# 7111               HCI College - Fort Lauderdale Campus  Fort Lauderdale
#
#      STABBR        ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 7107     AZ  853656900           NaN      NaN     NaN  ...
# 7108     CA      95113           NaN      NaN     NaN  ...
# 7109     CA      93301           NaN      NaN     NaN  ...
# 7110     MA  021480000           NaN      NaN     NaN  ...
# ...

# %% [markdown]
# Looking at a random sample of 5 colleges

# %%
data.sample(5)  # printing random 5 rows from the data
# Out:
#       UNITID    OPEID  OPEID6                               INSTNM  \
# 3165  216454  2174400   21744             Triangle Tech Inc-Dubois
# 6498  487913  4240600   42406             Tri-State Barber College
# 1261  155353  2134800   21348      Old Town Barber College-Wichita
# 2895  209108   319900    3199                Marylhurst University
# 3428  224271  1076100   10761  Dallas Institute of Funeral Service
#
#              CITY STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 3165  Falls Creek     PA  15840-3333           NaN      NaN     NaN  ...
# 6498      Ashland     KY  41101-7746           NaN      NaN     NaN  ...
# 1261      Wichita     KS  67211-1605           NaN      NaN     NaN  ...
# 2895   Marylhurst     OR  97036-0261           NaN      NaN     NaN  ...
# 3428       Dallas     TX  75227-4314           NaN      NaN     NaN  ...
#
#       OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN  UG12MN  G12MN  \
# ...

# %% [markdown]
# Since there are too many variables to explore, many of which are not interesting. Create a smaller data frame with the following 9 variables:
#
# UNITID,INSTNM,CITY,STABBR,ZIP,ADM_RATE,UGDS,TUITIONFEE_IN,MN_EARN_WNE_P10

# %%
# creating a smaller data set with the required columns
new_data=data[['UNITID','INSTNM','CITY','STABBR','ZIP','ADM_RATE','UGDS','TUITIONFEE_IN','MN_EARN_WNE_P10']]
new_data
# Out:
#         UNITID                                             INSTNM  \
# 0       100654                           Alabama A & M University
# 1       100663                University of Alabama at Birmingham
# 2       100690                                 Amridge University
# 3       100706                University of Alabama in Huntsville
# 4       100724                           Alabama State University
# ...        ...                                                ...
# 7107  48312404                   Arizona State University at Yuma
# 7108  48387801  Bay Area Medical Academy - San Jose Satellite ...
# 7109  48400201           High Desert Medical College - Bakerfield
# 7110  48778201                                       BCI - Malden
# 7111  49005401               HCI College - Fort Lauderdale Campus
#
#                  CITY STABBR         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  \
# 0              Normal     AL       35762    0.9027   4824.0         9857.0
# ...

# %% [markdown]
# **UNITID**:Integer
#
# Data files are provided at the UNITID level, which is the unique
# identification number assigned to postsecondary institutions as
# surveyed through IPEDS.
#
# **INSTNM**:String
#
# The institution’s name (INSTNM), as reported in IPEDS.
#
# ***CITY:***String
#
# The institution’s location, as reported in IPEDS
#
# **STABR**:String
#
# The institution’s location, as reported in IPEDS
#
# **ZIP**:String
# The institution’s location, as reported in IPEDS
#
# **ADM_RATE**:Float
#
# Colleges report to IPEDS their Fall admissions rate, defined as the
# number of admitted undergraduates divided by the number of
# undergraduates who applied. For institutions with multiple branches,
# ADM_RATE includes the admissions rate at each campus, while
# ADM_RATE_ALL represents the admissions rate across all campuses,
# defined as the total number of admitted undergraduates across all
# branches divided by the total number of undergraduates who applied
# across all branches. Please note these are also often referred to as
# acceptance rates
#
#
# **UGDS**: Integer
#
# This element (UGDS) includes the number of degree/certificate-seeking
# undergraduates enrolled in the fall, as reported in the IPEDS Fall
# Enrollment component
#
# **TUITIONFEE_IN**:Tuition
# and required fees are provided for in-state students (TUITIONFEE_IN)
#
# **MN_EARN_WNE_P10**:Mean (MN_EARN_WNE_P*) earnings are for the institutional
# aggregate of all federally aided undergraduate students who
# enroll in an institution each year and who are employed but not
# enrolled

# %% [markdown]
# Look at the first 10 colleges

# %%
new_data.head(10)   # printing first 10 rows of new data
# Out:
#    UNITID                               INSTNM            CITY STABBR  \
# 0  100654             Alabama A & M University          Normal     AL
# 1  100663  University of Alabama at Birmingham      Birmingham     AL
# 2  100690                   Amridge University      Montgomery     AL
# 3  100706  University of Alabama in Huntsville      Huntsville     AL
# 4  100724             Alabama State University      Montgomery     AL
# 5  100751            The University of Alabama      Tuscaloosa     AL
# 6  100760    Central Alabama Community College  Alexander City     AL
# 7  100812              Athens State University          Athens     AL
# 8  100830      Auburn University at Montgomery      Montgomery     AL
# 9  100858                    Auburn University          Auburn     AL
#
#           ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0       35762    0.9027   4824.0         9857.0              NaN
# 1  35294-0110    0.9181  12866.0         8328.0              NaN
# ...

# %% [markdown]
# Look at the last 10 colleges

# %%
new_data.tail(10)  # printing last 10 rows of the new data
# Out:
#         UNITID                                             INSTNM  \
# 7102  48154401  National Personal Training Institute of Cleveland
# 7103  48305401             Barber School of Pittsburgh - Ambridge
# 7104  48312401                 Arizona State University at Tucson
# 7105  48312402  Arizona State University - ASU Colleges at Lak...
# 7106  48312403        Arizona State University at The Gila Valley
# 7107  48312404                   Arizona State University at Yuma
# 7108  48387801  Bay Area Medical Academy - San Jose Satellite ...
# 7109  48400201           High Desert Medical College - Bakerfield
# 7110  48778201                                       BCI - Malden
# 7111  49005401               HCI College - Fort Lauderdale Campus
#
#                   CITY STABBR        ZIP  ADM_RATE  UGDS  TUITIONFEE_IN  \
# 7102  Highland Heights     OH      44143       NaN   NaN            NaN
# 7103          Ambridge     PA  150030000       NaN   NaN            NaN
# ...

# %% [markdown]
# Look at the random sample of 10 colleges

# %%
new_data.sample(10)   # printing random 10 rows of new data
# Out:
#       UNITID                                             INSTNM  \
# 334   116350       Toni & Guy Hairdressing Academy-Santa Monica
# 3727  234933                                      Clark College
# 768   137591                              Bene's Career Academy
# 3475  226374                               Lubbock Hair Academy
# 1595  167288              Massachusetts College of Liberal Arts
# 198   109819                                Bakersfield College
# 739   136330                     Palm Beach Atlantic University
# 2620  200624  The Art Institute of Cincinnati-AIC College of...
# 1513  164580                                     Babson College
# 5124  446039  Arizona School of Acupuncture and Oriental Med...
#
#                  CITY STABBR         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  \
# 334      Santa Monica     CA       90401       NaN    222.0            NaN
# 3727        Vancouver     WA  98663-3598       NaN   8170.0         3613.0
# ...

# %% [markdown]
# Find and display UMBC

# %%
df1=new_data.loc[new_data['INSTNM'] == "University of Maryland-Baltimore County"]  # searching for umbc
df1
# Out:
#       UNITID                                   INSTNM       CITY STABBR  \
# 1478  163268  University of Maryland-Baltimore County  Baltimore     MD
#
#         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1478  21250    0.6021  11130.0        11518.0              NaN

# %% [markdown]
# Find Univ. of Maryland College Park

# %%
df2=new_data.loc[new_data['INSTNM'] == "University of Maryland-College Park"] # searching for college park
df2
# Out:
#       UNITID                               INSTNM          CITY STABBR    ZIP  \
# 1479  163286  University of Maryland-College Park  College Park     MD  20742
#
#       ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1479     0.445  29273.0        10399.0              NaN

# %% [markdown]
# Find and display Loyola College Maryland

# %%
df3=new_data.loc[new_data['INSTNM'] == "Loyola University Maryland"]   #searching for loyola college
df3
# Out:
#       UNITID                      INSTNM       CITY STABBR         ZIP  \
# 1475  163046  Loyola University Maryland  Baltimore     MD  21210-2699
#
#       ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1475    0.7528  3903.0        47560.0              NaN

# %% [markdown]
# Find and display Johns Hopskins

# %%
df4=new_data.loc[new_data['INSTNM'] == "Johns Hopkins University"]  # searching for john hopkins
df4
# Out:
#       UNITID                    INSTNM       CITY STABBR         ZIP  \
# 1473  162928  Johns Hopkins University  Baltimore     MD  21218-2688
#
#       ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1473    0.1254  5663.0        52170.0              NaN

# %%
df = pd.concat([df1,df2, df3,df4], ignore_index=True)       # joining all the above dataframes to form small new dataframe using concat function
df
# Out:
#    UNITID                                   INSTNM          CITY STABBR  \
# 0  163268  University of Maryland-Baltimore County     Baltimore     MD
# 1  163286      University of Maryland-College Park  College Park     MD
# 2  163046               Loyola University Maryland     Baltimore     MD
# 3  162928                 Johns Hopkins University     Baltimore     MD
#
#           ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0       21250    0.6021  11130.0        11518.0              NaN
# 1       20742    0.4450  29273.0        10399.0              NaN
# 2  21210-2699    0.7528   3903.0        47560.0              NaN
# 3  21218-2688    0.1254   5663.0        52170.0              NaN

# %% [markdown]
# Calculate the min, max, and average in-state tution of the above four institutions.

# %%
df[df["TUITIONFEE_IN"] == df["TUITIONFEE_IN"].max()]  # finidng the row with maximum tutuion fee
# Out:
#    UNITID                    INSTNM       CITY STABBR         ZIP  ADM_RATE  \
# 3  162928  Johns Hopkins University  Baltimore     MD  21218-2688    0.1254
#
#      UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 3  5663.0        52170.0              NaN

# %%
df[df["TUITIONFEE_IN"] == df["TUITIONFEE_IN"].min()]   # finding the row with minimum tutuion fee
# Out:
#    UNITID                               INSTNM          CITY STABBR    ZIP  \
# 1  163286  University of Maryland-College Park  College Park     MD  20742
#
#    ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1     0.445  29273.0        10399.0              NaN

# %%
df["TUITIONFEE_IN"].mean()    # finding the average tution fee of all the four universites
# Out:
# 30411.75

# %% [markdown]
# Filter the smaller dataset further to only keep colleges from Maryland, Virgina, Washington DC, Delaware, and Pennsylvinia. Save the filtered dataset to a new file named "Five_States_Colleges.csv" for future analysis

# %%
new_df1=new_data.loc[new_data['STABBR'] == "MD"]    # searching for colleges in maryland
new_df1
# Out:
#         UNITID                                  INSTNM          CITY STABBR  \
# 1446    161651     Aesthetics Institute of Cosmetology  Gaithersburg     MD
# 1447    161688            Allegany College of Maryland    Cumberland     MD
# 1448    161767          Anne Arundel Community College        Arnold     MD
# 1449    161776               Brightwood College-Towson        Towson     MD
# 1450    161800                     Award Beauty School    Hagerstown     MD
# ...        ...                                     ...           ...    ...
# 6800  16210401          Cecil College - Elkton Station        Elkton     MD
# 7004  43018401     Strayer University-Rockville Campus     Rockville     MD
# 7005  43018402  Strayer University-Anne Arundel Campus  Millersville     MD
# 7006  43018403   Strayer University-White Marsh Campus     Baltimore     MD
# 7007  43018404  Strayer University-Owings Mills Campus  Owings Mills     MD
#
# ...

# %%
new_df2=new_data.loc[new_data['STABBR'] == "DC"]    # searching for colleges in washington DC
new_df2
# Out:
#         UNITID                                             INSTNM        CITY  \
# 643     131159                                American University  Washington
# 644     131283                 The Catholic University of America  Washington
# 645     131399             University of the District of Columbia  Washington
# 646     131405  Pontifical Faculty of the Immaculate Conceptio...  Washington
# 647     131450                               Gallaudet University  Washington
# 648     131469                       George Washington University  Washington
# 649     131496                              Georgetown University  Washington
# 650     131520                                  Howard University  Washington
# 651     131803            Strayer University-District of Columbia  Washington
# 652     131830             National Conservatory of Dramatic Arts  Washington
# 653     131876                      Trinity Washington University  Washington
# ...

# %%
new_df3=new_data.loc[new_data['STABBR'] == "VA"]   # searcing for colleges in viriginia
new_df3
# Out:
#         UNITID                                          INSTNM  \
# 3627    231280                Paul Mitchell the School-Roanoke
# 3628    231411                   Advanced Technology Institute
# 3629    231420                              Averett University
# 3630    231536                    Blue Ridge Community College
# 3631    231554                               Bluefield College
# ...        ...                                             ...
# 6969  24893411  ECPI University-Virginia Beach Health Sciences
# 6970  24893412                  ECPI University-Richmond South
# 6971  24893413                       ECPI University-Innsbrook
# 6972  24893414                   ECPI University-Richmond West
# 6973  24893415                       ECPI University - Roanoke
#
#                 CITY STABBR         ZIP  ADM_RATE    UGDS  TUITIONFEE_IN  \
# 3627         Roanoke     VA       24015       NaN    84.0            NaN
# ...

# %%
new_df4=new_data.loc[new_data['STABBR'] == "PA"]    # searching for colleges in penselvinia
new_df4
# Out:
#         UNITID                                             INSTNM  \
# 2933    210474             Jolie Hair and Beauty Academy-Hazleton
# 2934    210492               Bryn Athyn College of the New Church
# 2935    210508                              Academy of Vocal Arts
# 2936    210571                                   Albright College
# 2937    210599                            All-State Career School
# ...        ...                                                ...
# 7023  44378405               Strayer University-Warrendale Campus
# 7024  44378406                Strayer University-Allentown Campus
# 7063  45794301   Somerset County Technology Center - Bedford Site
# 7089  47503308  Relay Graduate School of Education - Philadelp...
# 7103  48305401             Barber School of Pittsburgh - Ambridge
#
#                CITY STABBR         ZIP  ADM_RATE    UGDS  TUITIONFEE_IN  \
# 2933       Hazleton     PA       18201       NaN    61.0            NaN
# ...

# %%
new_df5=new_data.loc[new_data['STABBR'] == "DE"]   # searching for collegs in delaware
new_df5
# Out:
#         UNITID                                             INSTNM        CITY  \
# 634     130837  Margaret H Rollins School of Nursing at Beebe ...       Lewes
# 635     130873                          Dawn Career Institute LLC      Newark
# 636     130907         Delaware Technical Community College-Terry       Dover
# 637     130934                          Delaware State University       Dover
# 638     130943                             University of Delaware      Newark
# 639     130989                              Goldey-Beacom College  Wilmington
# 640     131061        Schilling-Douglas School of Hair Design LLC      Newark
# 641     131098                                     Wesley College       Dover
# 642     131113                              Wilmington University  New Castle
# 4729    432524                 Delaware College of Art and Design  Wilmington
# 4917    441362        Harris School of Business-Wilmington Campus  Wilmington
# ...

# %%
final_df = pd.concat([new_df1,new_df2,new_df3,new_df4,new_df5], ignore_index=True)   # concatinating all the above 5 dataframes to get new dataframe
final_df
# Out:
#        UNITID                                             INSTNM  \
# 0      161651                Aesthetics Institute of Cosmetology
# 1      161688                       Allegany College of Maryland
# 2      161767                     Anne Arundel Community College
# 3      161776                          Brightwood College-Towson
# 4      161800                                Award Beauty School
# ..        ...                                                ...
# 685    459301                  Paul Mitchell the School-Delaware
# 686    488262          Hair Academy School of Barbering & Beauty
# 687  13090701         Delaware Technical Community College-Owens
# 688  13090702  Delaware Technical Community College-Stanton/W...
# 689  47503303      Relay Graduate School of Education - Delaware
#
#              CITY STABBR         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  \
# 0    Gaithersburg     MD       20877       NaN     25.0            NaN
# ...

# %%
    final_df.to_csv('Five_States_Colleges.csv', index=False)     # downloading the merged dataset with colleges data on 5 staes

# %% [markdown]
# ref:
#
#  1.https://www.statology.org/pandas-select-rows-based-on-column-values/
#
# 2.https://www.statology.org/pandas-append-multiple-dataframes/
